# %% [markdown]
# <a href="https://colab.research.google.com/github/07shi/PYTHON/blob/main/Pandas%20Data%20Frame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.DataFrame()
print(df)
lst = ['A', 'B', 'C', 'D', 'E', 'F', 'G']

df = pd.DataFrame(lst)
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []
#    0
# 0  A
# 1  B
# 2  C
# 3  D
# 4  E
# 5  F
# 6  G
