# %% [markdown]
# <a href="https://colab.research.google.com/github/07shi/PYTHON/blob/main/Pandas%20Series.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
data = np.array(['a', 'b', 'c', 'd', 'e'])

s = pd.Series(data)
print("Pandas Series:\n", s)
# Out:
# Pandas Series:
#  0    a
# 1    b
# 2    c
# 3    d
# 4    e
# dtype: object
